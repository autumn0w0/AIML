# %% [markdown]
# Store following word meanings in a python dictionary:
#
# table: "a piece of furniture", "list of facts & figures"
#
# cat: "a small animal"

# %%
dist = {"cat" : "a small animal",
        "table" : ["a piece of furniture","list of facts and figures"]
}
print(dist)
# Out:
# {'cat': 'a small animal', 'table': ['a piece of furniture', 'list of facts and figures']}

# %% [markdown]
# You are given a list of subjects for students. Assume one classroom is required for 1 subject. How many classrooms are needed by all students.
#
# "python", "java", "C++", "python", "javascript", "java", "python", "java", "C++", "C"

# %%
sub = {"python", "java", "C++", "python", "javascript", "java", "python", "java", "C++", "C"}
print("no. of classes reqd are:", len(sub))
# Out:
# no. of classes reqd are: 5

# %% [markdown]
# WAP to enter marks of 3 subjects from the user and store them in a dictionary. Start with an empty dictionary & add one by one. Use subject name as key & marks as value.

# %%
val1 = float(input("enter the value of val1:"))
val2 = float(input("enter the value of val2:"))
val3 = float(input("enter the value of val3:"))

dict = {"subject1": val1,
        "subject2": val2,
        "subject3": val3}
print(dict)

null_dict = {}
null_dict.update({"subject1": val1, 
                    "subject2": val2, 
                    "subject3": val3})
print(null_dict)
# Out:
# {'subject1': 1.0, 'subject2': 2.0, 'subject3': 34.0}
# {'subject1': 1.0, 'subject2': 2.0, 'subject3': 34.0}

# %% [markdown]
# Figure out a way to store 9 & 9.0 as separate values in the set.
# (You can take help of built-in data types)

# %%
set = {"float":9.0,
       "int": 9,}
print(set)
# Out:
# {'float': 9.0, 'int': 9}
